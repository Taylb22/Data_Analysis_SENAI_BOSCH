# %%
# Tarefa 1

detalhes_produto_bosch = {'id_produto': "BOSCH-XYZ-123", 'nome': "Sensor de Temperatura Inteligente", 'versao': 2.1, 'fabricado_em': "Alemanha", 'componentes': ['chip_principal', 'resistor_termico', 'conector_usb']}

print("--- Built - ins ---")
print(f"Chaves: {detalhes_produto_bosch.keys()}")
print(f"Valores: {detalhes_produto_bosch.values()}")
print(f"Itens (chave-valor): {detalhes_produto_bosch.items()}")
# Out:
# --- Built - ins ---
# Chaves: dict_keys(['id_produto', 'nome', 'versao', 'fabricado_em', 'componentes'])
# Valores: dict_values(['BOSCH-XYZ-123', 'Sensor de Temperatura Inteligente', 2.1, 'Alemanha', ['chip_principal', 'resistor_termico', 'conector_usb']])
# Itens (chave-valor): dict_items([('id_produto', 'BOSCH-XYZ-123'), ('nome', 'Sensor de Temperatura Inteligente'), ('versao', 2.1), ('fabricado_em', 'Alemanha'), ('componentes', ['chip_principal', 'resistor_termico', 'conector_usb'])])

# %%
# Tarefa 2

producao_por_linha = {'Linha A': 1200, 'Linha B': 1500, 'Linha C': 950, 'Linha D': 1350}

print(f"Produçãoo inicial por linha: {producao_por_linha}")
producao_por_linha['Linha E'] = 1100
print(f"Produção após adicionar a Linha E: {producao_por_linha}")

print(f"Removido Linha C: {producao_por_linha.pop('Linha C')} peças produzidas.")
print(f"Produção após remover a Linha C: {producao_por_linha}")

print(f"Número de linhas ativas: {len(producao_por_linha)}")

producao_por_linha.clear()

print(f"Produção após limpas: {producao_por_linha}")
# Out:
# Produçãoo inicial por linha: {'Linha A': 1200, 'Linha B': 1500, 'Linha C': 950, 'Linha D': 1350}
# Produção após adicionar a Linha E: {'Linha A': 1200, 'Linha B': 1500, 'Linha C': 950, 'Linha D': 1350, 'Linha E': 1100}
# Removido Linha C: 950 peças produzidas.
# Produção após remover a Linha C: {'Linha A': 1200, 'Linha B': 1500, 'Linha D': 1350, 'Linha E': 1100}
# Número de linhas ativas: 4
# Produção após limpas: {}

# %%
carrinho_cliente = {'Mouse sem fio': 
                    {'Quantidade': 2,
                     'preco_unitario': 25.50
                    },
                    'Teclado Mecânico':
                    {'Quantidade': 3,
                     'preco_unitario': 120.00
                    } 
                    }

print(f"Carrinho do Cliente:\n{carrinho_cliente}")

print(f"Quantidade de Mouse sem fio: {carrinho_cliente["Mouse sem fio"]["Quantidade"]}")
# Out:
# Carrinho do Cliente:
# {'Mouse sem fio': {'Quantidade': 2, 'preco_unitario': 25.5}, 'Teclado Mecânico': {'Quantidade': 3, 'preco_unitario': 120.0}}
# Quantidade de Mouse sem fio: 2
