# %%
# Tarefa 1

producao_diaria = [500, 650, 480]

print(f"Produção diária: {producao_diaria}")
print(f"Produção do segundo turno: {producao_diaria[1]}")

producao_diaria.append(550)

print(f"Produção diária atualizada com o quarto turno: {producao_diaria}")
# Out:
# Produção diária: [500, 650, 480]
# Produção do segundo turno: 650
# Produção diária atualizada com o quarto turno: [500, 650, 480, 550]

# %%
# Tarefa 2

materiais_disponiveis = ['aço', 'plástico','alumínio', 'borracha']
print(f"Materiais antes da remoção: {materiais_disponiveis}")

materiais_disponiveis.remove('borracha')
print(f"Materiais depois da remoção: {materiais_disponiveis}")

if 'plástico' in materiais_disponiveis:
    print("Plástico está disponível no estoque.")
else:
    print("Plástico NÃO está disponível no estoque.")

materiais_disponiveis.sort()
print(f"Materiais ordenados: {materiais_disponiveis}")
# Out:
# Materiais antes da remoção: ['aço', 'plástico', 'alumínio', 'borracha']
# Materiais depois da remoção: ['aço', 'plástico', 'alumínio']
# Plástico está disponível no estoque.
# Materiais ordenados: ['alumínio', 'aço', 'plástico']

# %%
# Tarefa 3

leituras_temperatura = [85.5, 87.2, 86.8, 89.0, 85.9]

soma = 0.0
for temperatura in leituras_temperatura:
    soma += temperatura

media = soma / len(leituras_temperatura)
maximo = max(leituras_temperatura)

print(f"Temperatura média: {media:.2f}°C\nTemperatura máxima registrada: {maximo:.1f}°C")
# Out:
# Temperatura média: 86.88°C
# Temperatura máxima registrada: 89.0°C

# %%
# Tarefa 4

configuracao_maquina = ('MEC-001', 'Soldagem', 120)
print(f"Configuração completa de máquina: {configuracao_maquina}")

print(f"ID da Máquina: {configuracao_maquina[0]}\nTipo de Operação: {configuracao_maquina[1]}\nVelocidade Padrão: {configuracao_maquina[2]}")

configuracao_maquina[2] = 130

# Erro ocorre pois a tupla possui valores fixos em sua criação que não podem ser alterados, como se fosse uma "lista de constantes" (pode ser útil para criar cabeçalhos por exemplo)
# Out:
# Configuração completa de máquina: ('MEC-001', 'Soldagem', 120)
# ID da Máquina: MEC-001
# Tipo de Operação: Soldagem
# Velocidade Padrão: 120
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       4 print(f"Configuração completa de máquina: {configuracao_maquina}")
#       6 print(f"ID da Máquina: {configuracao_maquina[0]}\nTipo de Operação: {configuracao_maquina[1]}\nVelocidade Padrão: {configuracao_maquina[2]}")
# ----> 8 configuracao_maquina[2] = 130
#      10 # Erro ocorre pois a tupla possui valores fixos em sua criação que não podem ser alterados, como se fosse uma "lista de constantes" (pode ser útil para criar cabeçalhos por exemplo)
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Tarefa 5

sensor_1 = (50.5, 25.2)
sensor_2 = (75.0, 30.8)

lista_sensores = [sensor_1, sensor_2]

print(f"Lista de coordenada dos sensores: {lista_sensores}")

print(f"Coordenada X do segundo sensor: {lista_sensores[1][0]:.1f}")
# Out:
# Lista de coordenada dos sensores: [(50.5, 25.2), (75.0, 30.8)]
# Coordenada X do segundo sensor: 75.0
